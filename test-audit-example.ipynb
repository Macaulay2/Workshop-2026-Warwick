# %%
needsPackage "TestAudit"
help testAudit
# Out:
# o1 = TestAudit
#
# o1 : Package
# o2 = testAudit -- produce a test audit report for a package
#      ******************************************************
#
#        * Usage:
#              testAudit pkg
#              testAudit(pkg, CommentReport => true, SpeedReport => true, ScoreReport => true)
#        * Inputs:
#            * pkg, a "package" or a "string",
#        * "Optional inputs":
#            * CommentReport => a "Boolean value", default value false
#            * SpeedReport => a "Boolean value", default value false
#            * ScoreReport => a "Boolean value", default value false
#            * "Experimental" => ..., default value false,
#        * Outputs:
#            * a "string", the audit report
#
#      Description
# ...
#
#      Returns a string report about the tests of pkg. The default report
#      summarizes test sources, test organization, untested exported functions and
#      options, silenced tests, and FIXME or TODO markers around test blocks.
#
# ...

# %%
%mode standard
testAudit "Probability"
# Out:
# o4 = exported: 19 functions, 3 types, 6 other symbols; 3 methods on external functions
#      n_tests: 20
#      style: together
#
#      test sources:
#          - /opt/homebrew/Cellar/macaulay2/1.26.06_1/share/Macaulay2/Probability.m2:1281
#
#      Report:
#
#      - untested functions (4):
#          - density
#          - probability
#          - quantile
#          - texMath
#
#      - untested options (5):
#          - random: CoefficientRing
#          - random: Density
#          - random: Height
#          - random: MaximalRank
#          - random: UpperTriangular
#
#      - silenced tests (0):
#          none
#
#      - FIXME/TODO markers (0):
#          none

# %%
testAudit("Probability", CommentReport => true)
# Out:
# o5 = exported: 19 functions, 3 types, 6 other symbols; 3 methods on external functions
#      n_tests: 20
#      style: together
#
#      test sources:
#          - /opt/homebrew/Cellar/macaulay2/1.26.06_1/share/Macaulay2/Probability.m2:1281
#
#      Report:
#
#      - untested functions (4):
#          - density
#          - probability
#          - quantile
#          - texMath
#
#      - untested options (5):
#          - random: CoefficientRing
#          - random: Density
#          - random: Height
#          - random: MaximalRank
#          - random: UpperTriangular
#
#      - silenced tests (0):
#          none
#
#      - FIXME/TODO markers (0):
#          none
#
#
#      Comments:
#
#      TEST 13 -- source: /opt/homebrew/Cellar/macaulay2/1.26.06_1/share/Macaulay2/Probability.m2:1466:5-1484:3
#      ------------------------------------------------------------------------
#      Header comments:
#      In-test comments:
#          -- sum of two dice
#
# ...

# %%
testAudit("Probability", SpeedReport => true)
# Out:
# -- capturing check(0, "Probability")            -- .06818s elapsed
#  -- capturing check(1, "Probability")            -- .0658536s elapsed
#  -- capturing check(2, "Probability")            -- .0659629s elapsed
#  -- capturing check(3, "Probability")            -- .0663092s elapsed
#  -- capturing check(4, "Probability")            -- .0668373s elapsed
#  -- capturing check(5, "Probability")            -- .0690031s elapsed
#  -- capturing check(6, "Probability")            -- .0704783s elapsed
#  -- capturing check(7, "Probability")            -- .0688774s elapsed
#  -- capturing check(8, "Probability")            -- .069385s elapsed
#  -- capturing check(9, "Probability")            -- .0691525s elapsed
#  -- capturing check(10, "Probability")           -- .0701447s elapsed
#  -- capturing check(11, "Probability")           -- .0678229s elapsed
#  -- capturing check(12, "Probability")           -- .0673302s elapsed
# ...

# %%
testAudit("Probability", ScoreReport => true)
# Out:
# o7 = exported: 19 functions, 3 types, 6 other symbols; 3 methods on external functions
#      n_tests: 20
#      style: together
#
#      test sources:
#          - /opt/homebrew/Cellar/macaulay2/1.26.06_1/share/Macaulay2/Probability.m2:1281
#
#      Report:
#
#      - untested functions (4):
#          - density
#          - probability
#          - quantile
#          - texMath
#
#      - untested options (5):
#          - random: CoefficientRing
#          - random: Density
#          - random: Height
#          - random: MaximalRank
#          - random: UpperTriangular
#
#      - silenced tests (0):
#          none
#
#      - FIXME/TODO markers (0):
#          none
#
#
#      ScoreReport: 81.6667 out of 100
#          tested: 61.6667 out of 80
#          exports covered: 82.1429% (23/28)
#          functions covered: 81.8182% (18/22)
#          types covered: 66.6667% (2/3)
#          other exports covered: 83.3333% (5/6)
#          options covered: 70.5882% (12/17)
# ...
